# %%
import pandas as pd

# %%
df = pd.read_csv("docker_stats.csv")
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')

# %%
df
# Out:
#              Timestamp     Container                        Name  \
# 0  2025-02-26 03:57:33  ed091606c583       reverse-proxy-cache-1
# 1  2025-02-26 03:57:33  0fe0a8dc05e3       reverse-proxy-agent-1
# 2  2025-02-26 03:57:33  14ddf6c731f6          reverse-proxy-lb-1
# 3  2025-02-26 03:57:33  99faca2b66dd  reverse-proxy-controller-1
# 4  2025-02-26 03:57:33  ea08cbd0427a         reverse-proxy-api-1
# 5  2025-02-26 03:57:45  ed091606c583       reverse-proxy-cache-1
# 6  2025-02-26 03:57:45  0fe0a8dc05e3       reverse-proxy-agent-1
# 7  2025-02-26 03:57:45  14ddf6c731f6          reverse-proxy-lb-1
# 8  2025-02-26 03:57:45  99faca2b66dd  reverse-proxy-controller-1
# 9  2025-02-26 03:57:45  ea08cbd0427a         reverse-proxy-api-1
# 10 2025-02-26 03:57:58  ed091606c583       reverse-proxy-cache-1
# 11 2025-02-26 03:57:58  0fe0a8dc05e3       reverse-proxy-agent-1
# 12 2025-02-26 03:57:58  14ddf6c731f6          reverse-proxy-lb-1
# ...
